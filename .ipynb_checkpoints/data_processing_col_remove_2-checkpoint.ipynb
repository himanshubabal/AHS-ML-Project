# %%
import pandas as pd
import numpy as np
import h5py
import matplotlib.pyplot as plt

import math
import os
from keras.utils.np_utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
data_path = 'data/'

# %%
def replace_labes(label_data):
	    dict_map = {0.0 : 0.0, 1.0 : 1.0, 2.0 : 2.0, 3.0 : 3.0, 7.0 : 4.0, 9.0 : 5.0,
	                19.0 : 6.0, 21.0 : 7.0, 99.0 : 7.0}
	    for i in range(len(label_data)):
	        if label_data[i] in dict_map:
	            label_data[i] = dict_map[label_data[i]]-1
	        else :
	            label_data[i] = 0.0
	    return label_data

def check_unnamed(dataframe):
	if 'Unnamed: 0' in list(dataframe):
		dataframe = dataframe.drop('Unnamed: 0',axis=1,errors='ignore')
	return dataframe

def find_hot_matches(col_index_list_to_remove, hot_col_names_list):
    hot_index_list = list()

    for cold in col_index_list_to_remove:
        for hot in hot_col_names_list:
            if cold in hot:
                print(hot)
                index = hot_col_names_list.index(hot)
                if index not in hot_index_list :
                    hot_index_list.append(index)
    print('----')
    return (hot_index_list)

# %%
diagnosed_data = pd.read_csv(data_path + '22_COMB_diag_hotData.csv', low_memory=False)
diagnosed_col = pd.read_csv(data_path + '22_COMB_diag_col.csv', low_memory=False)

# %%
cold_col_names_list = pd.read_csv(data_path + 'diagnosed_for_col_names.csv', low_memory=False)
cold_col_names_list = check_unnamed(cold_col_names_list)
cold_col_names_list = cold_col_names_list[cold_col_names_list.columns[0]].tolist()

# %%
cold_col_names_list[10]
# Out:
# 'highest_qualification'

# %%
def split_data(diagnosed_data, diagnosed_col, col_index_list_to_remove):
	# diagnosed_data = pd.read_csv(data_path + '22_COMB_diag_hotData.csv', low_memory=False)
	# diagnosed_col = pd.read_csv(data_path + '22_COMB_diag_col.csv', low_memory=False)

	# Checking if column 'Unnamed : 0' is in the dataframe
	# If present, remove it
	diagnosed_col = check_unnamed(diagnosed_col)
	diagnosed_data = check_unnamed(diagnosed_data)

	# cold_col_names = pd.read_csv(data_path + 'diagnosed_for_col_names.csv')
	# cold_col_names = check_unnamed(cold_col_names)
	# cold_col_names = cold_col_names[cold_col_names.columns[0]].tolist()

	hol_col_names_list = list(diagnosed_data)
	to_remove_hot_col = find_hot_matches(col_index_list_to_remove, hot_col_names_list)

	diagnosed_data.drop(diagnosed_data.columns[to_remove_hot_col],axis=1,inplace=True,errors='ignore')
	new_hot_col_list = list(diagnosed_data)

	assert (diagnosed_data.shape[0] == diagnosed_col.shape[0])
	split_train = int(diagnosed_data.shape[0] * 0.60)
	split_test = split_train + int(diagnosed_data.shape[0] * 0.25)

	diagnosed_data = np.array(diagnosed_data.astype(float))
	diagnosed_col = np.array(diagnosed_col.astype(float))[:,0]

	diagnosed_col = replace_labes(diagnosed_col)
	diagnosed_col = to_categorical(diagnosed_col.astype('int32'), nb_classes=None)

	train_data = diagnosed_data[:split_train]
	train_label = diagnosed_col[:split_train]

	test_data = diagnosed_data[split_train:split_test]
	test_label = diagnosed_col[split_train:split_test]

	valid_data = diagnosed_data[split_test:]
	valid_label = diagnosed_col[split_test:]

	# train_rep = replace_labes(train_label)
	# test_rep = replace_labes(test_label)
	# valid_rep = replace_labes(valid_rep)

	# train_label = to_categorical(train_rep.astype('int32'), nb_classes=None)
	# test_label = to_categorical(test_rep.astype('int32'), nb_classes=None)
	# valid_label = to_categorical(valid_rep.astype('int32'), nb_classes=None)

	print('Old features : ', hol_col_names_list)
	print()
	print('New features : ', new_hot_col_list)
	print()
	print('Features Removed : ', col_index_list_to_remove)
	print('Train dataset : ', train_data.shape, train_label.shape)
	print('Test dataset : ', test_data.shape, test_label.shape)
	print('Validation Dataset : ', valid_data.shape, valid_label.shape)

	return(train_data, train_label, test_data, test_label, valid_data, valid_label)

# %%
tr, trl, ts, tsl, v, vl = split_data(diagnosed_data, diagnosed_col, cold_col_names_list[10])
# Out:
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# sought_medical_care
# chew
# alcohol
# house_status
# house_structure
# is_toilet_shared
# household_have_electricity
# lighting_source
# kitchen_availability
# is_telephone
# is_washing_machine
# is_sewing_machine
# iscoveredbyhealthscheme
# healthscheme_1
# healthscheme_2
# housestatus
# householdstatus
# district
# usual_residance
# religion
# social_group_code
# marital_status
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# occupation_status
# disability_status
# injury_treatment_type
# illness_type
# symptoms_pertaining_illness
# sought_medical_care
# diagnosed_for
# diagnosis_source
# drinking_water_source
# is_water_filter
# water_filteration
# toilet_used
# is_toilet_shared
# household_have_electricity
# lighting_source
# cooking_fuel
# kitchen_availability
# is_radio
# is_television
# is_computer
# is_telephone
# is_washing_machine
# is_refrigerator
# is_sewing_machine
# is_bicycle
# is_scooter
# is_car
# is_tractor
# is_water_pump
# residancial_status
# iscoveredbyhealthscheme
# as_binned
# age
# religion
# social_group_code
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# symptoms_pertaining_illness
# sought_medical_care
# diagnosed_for
# diagnosis_source
# regular_treatment
# regular_treatment_source
# drinking_water_source
# lighting_source
# cooking_fuel
# is_washing_machine
# is_refrigerator
# is_sewing_machine
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# sought_medical_care
# chew
# alcohol
# house_status
# house_structure
# is_toilet_shared
# household_have_electricity
# lighting_source
# kitchen_availability
# is_telephone
# is_washing_machine
# is_sewing_machine
# iscoveredbyhealthscheme
# healthscheme_1
# healthscheme_2
# housestatus
# householdstatus
# sex
# usual_residance
# age
# religion
# social_group_code
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# injury_treatment_type
# illness_type
# treatment_source
# symptoms_pertaining_illness
# sought_medical_care
# diagnosed_for
# diagnosis_source
# regular_treatment
# regular_treatment_source
# chew
# smoke
# house_status
# house_structure
# owner_status
# drinking_water_source
# is_water_filter
# water_filteration
# toilet_used
# is_toilet_shared
# household_have_electricity
# lighting_source
# cooking_fuel
# kitchen_availability
# is_television
# is_computer
# is_telephone
# is_washing_machine
# is_refrigerator
# is_sewing_machine
# is_bicycle
# is_scooter
# is_water_pump
# land_possessed
# residancial_status
# iscoveredbyhealthscheme
# healthscheme_1
# healthscheme_2
# housestatus
# householdstatus
# as_binned
# district
# sex
# usual_residance
# social_group_code
# marital_status
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# occupation_status
# disability_status
# illness_type
# treatment_source
# symptoms_pertaining_illness
# sought_medical_care
# diagnosed_for
# diagnosis_source
# regular_treatment_source
# smoke
# house_status
# house_structure
# owner_status
# drinking_water_source
# is_water_filter
# toilet_used
# is_toilet_shared
# household_have_electricity
# lighting_source
# is_radio
# is_television
# is_computer
# is_telephone
# is_washing_machine
# is_refrigerator
# is_sewing_machine
# is_bicycle
# is_scooter
# is_car
# is_tractor
# is_water_pump
# land_possessed
# residancial_status
# iscoveredbyhealthscheme
# healthscheme_1
# healthscheme_2
# housestatus
# householdstatus
# as_binned
# district
# marital_status
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# occupation_status
# disability_status
# injury_treatment_type
# illness_type
# treatment_source
# symptoms_pertaining_illness
# sought_medical_care
# regular_treatment
# regular_treatment_source
# house_status
# house_structure
# owner_status
# drinking_water_source
# is_water_filter
# water_filteration
# toilet_used
# is_toilet_shared
# household_have_electricity
# lighting_source
# kitchen_availability
# is_television
# is_computer
# is_telephone
# is_refrigerator
# is_scooter
# is_tractor
# is_water_pump
# cart
# residancial_status
# iscoveredbyhealthscheme
# healthscheme_1
# healthscheme_2
# housestatus
# householdstatus
# usual_residance
# social_group_code
# marital_status
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# occupation_status
# disability_status
# injury_treatment_type
# illness_type
# treatment_source
# symptoms_pertaining_illness
# sought_medical_care
# diagnosed_for
# diagnosis_source
# regular_treatment
# regular_treatment_source
# house_status
# house_structure
# owner_status
# drinking_water_source
# is_water_filter
# water_filteration
# toilet_used
# is_toilet_shared
# household_have_electricity
# lighting_source
# cooking_fuel
# kitchen_availability
# is_radio
# is_television
# is_computer
# is_telephone
# is_washing_machine
# is_refrigerator
# is_sewing_machine
# is_bicycle
# is_scooter
# is_car
# is_tractor
# is_water_pump
# land_possessed
# residancial_status
# healthscheme_1
# healthscheme_2
# as_binned
# highest_qualification
# rural
# usual_residance
# social_group_code
# marital_status
# currently_attending_school
# highest_qualification
# occupation_status
# disability_status
# injury_treatment_type
# treatment_source
# sought_medical_care
# diagnosis_source
# regular_treatment
# regular_treatment_source
# house_status
# house_structure
# owner_status
# drinking_water_source
# toilet_used
# household_have_electricity
# lighting_source
# cooking_fuel
# is_computer
# is_water_pump
# residancial_status
# housestatus
# householdstatus
# rural
# usual_residance
# age
# social_group_code
# marital_status
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# occupation_status
# disability_status
# injury_treatment_type
# treatment_source
# symptoms_pertaining_illness
# sought_medical_care
# diagnosed_for
# diagnosis_source
# regular_treatment
# regular_treatment_source
# alcohol
# house_status
# owner_status
# drinking_water_source
# is_water_filter
# water_filteration
# is_toilet_shared
# household_have_electricity
# kitchen_availability
# is_radio
# is_washing_machine
# is_refrigerator
# is_sewing_machine
# is_car
# is_tractor
# is_water_pump
# cart
# land_possessed
# residancial_status
# iscoveredbyhealthscheme
# healthscheme_1
# healthscheme_2
# housestatus
# householdstatus
# as_binned
# rural
# usual_residance
# religion
# social_group_code
# marital_status
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# disability_status
# illness_type
# symptoms_pertaining_illness
# sought_medical_care
# regular_treatment
# regular_treatment_source
# alcohol
# is_water_filter
# water_filteration
# toilet_used
# is_toilet_shared
# household_have_electricity
# lighting_source
# cooking_fuel
# kitchen_availability
# is_television
# is_telephone
# is_bicycle
# land_possessed
# residancial_status
# iscoveredbyhealthscheme
# healthscheme_1
# healthscheme_2
# householdstatus
# district
# usual_residance
# religion
# social_group_code
# marital_status
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# occupation_status
# disability_status
# injury_treatment_type
# illness_type
# symptoms_pertaining_illness
# sought_medical_care
# diagnosed_for
# diagnosis_source
# drinking_water_source
# is_water_filter
# water_filteration
# toilet_used
# is_toilet_shared
# household_have_electricity
# lighting_source
# cooking_fuel
# kitchen_availability
# is_radio
# is_television
# is_computer
# is_telephone
# is_washing_machine
# is_refrigerator
# is_sewing_machine
# is_bicycle
# is_scooter
# is_car
# is_tractor
# is_water_pump
# residancial_status
# iscoveredbyhealthscheme
# as_binned
# reason_for_not_attending_school
# highest_qualification
# diagnosed_for
# is_water_filter
# water_filteration
# cooking_fuel
# is_refrigerator
# district
# usual_residance
# religion
# social_group_code
# marital_status
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# occupation_status
# disability_status
# injury_treatment_type
# illness_type
# symptoms_pertaining_illness
# sought_medical_care
# diagnosed_for
# diagnosis_source
# drinking_water_source
# is_water_filter
# water_filteration
# toilet_used
# is_toilet_shared
# household_have_electricity
# lighting_source
# cooking_fuel
# kitchen_availability
# is_radio
# is_television
# is_computer
# is_telephone
# is_washing_machine
# is_refrigerator
# is_sewing_machine
# is_bicycle
# is_scooter
# is_car
# is_tractor
# is_water_pump
# residancial_status
# iscoveredbyhealthscheme
# as_binned
# district
# usual_residance
# social_group_code
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# occupation_status
# treatment_source
# sought_medical_care
# diagnosis_source
# regular_treatment_source
# chew
# alcohol
# house_structure
# drinking_water_source
# household_have_electricity
# lighting_source
# cooking_fuel
# kitchen_availability
# is_computer
# is_washing_machine
# is_sewing_machine
# is_bicycle
# is_scooter
# is_car
# is_tractor
# cart
# residancial_status
# iscoveredbyhealthscheme
# healthscheme_1
# healthscheme_2
# rural
# usual_residance
# age
# social_group_code
# marital_status
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# occupation_status
# disability_status
# injury_treatment_type
# treatment_source
# symptoms_pertaining_illness
# sought_medical_care
# diagnosed_for
# diagnosis_source
# regular_treatment
# regular_treatment_source
# alcohol
# house_status
# owner_status
# drinking_water_source
# is_water_filter
# water_filteration
# is_toilet_shared
# household_have_electricity
# kitchen_availability
# is_radio
# is_washing_machine
# is_refrigerator
# is_sewing_machine
# is_car
# is_tractor
# is_water_pump
# cart
# land_possessed
# residancial_status
# iscoveredbyhealthscheme
# healthscheme_1
# healthscheme_2
# housestatus
# householdstatus
# as_binned
# district
# marital_status
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# occupation_status
# disability_status
# injury_treatment_type
# illness_type
# treatment_source
# symptoms_pertaining_illness
# sought_medical_care
# regular_treatment
# regular_treatment_source
# house_status
# house_structure
# owner_status
# drinking_water_source
# is_water_filter
# water_filteration
# toilet_used
# is_toilet_shared
# household_have_electricity
# lighting_source
# kitchen_availability
# is_television
# is_computer
# is_telephone
# is_refrigerator
# is_scooter
# is_tractor
# is_water_pump
# cart
# residancial_status
# iscoveredbyhealthscheme
# healthscheme_1
# healthscheme_2
# housestatus
# householdstatus
# district
# usual_residance
# religion
# social_group_code
# marital_status
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# occupation_status
# disability_status
# injury_treatment_type
# illness_type
# symptoms_pertaining_illness
# sought_medical_care
# diagnosed_for
# diagnosis_source
# drinking_water_source
# is_water_filter
# water_filteration
# toilet_used
# is_toilet_shared
# household_have_electricity
# lighting_source
# cooking_fuel
# kitchen_availability
# is_radio
# is_television
# is_computer
# is_telephone
# is_washing_machine
# is_refrigerator
# is_sewing_machine
# is_bicycle
# is_scooter
# is_car
# is_tractor
# is_water_pump
# residancial_status
# iscoveredbyhealthscheme
# as_binned
# religion
# social_group_code
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# occupation_status
# treatment_source
# symptoms_pertaining_illness
# sought_medical_care
# diagnosed_for
# diagnosis_source
# regular_treatment_source
# smoke
# alcohol
# house_status
# house_structure
# owner_status
# drinking_water_source
# water_filteration
# toilet_used
# is_toilet_shared
# household_have_electricity
# lighting_source
# cooking_fuel
# is_radio
# is_television
# is_computer
# is_telephone
# is_refrigerator
# is_scooter
# is_tractor
# land_possessed
# iscoveredbyhealthscheme
# housestatus
# householdstatus
# usual_residance
# religion
# currently_attending_school
# reason_for_not_attending_school
# highest_qualification
# occupation_status
# injury_treatment_type
# illness_type
# treatment_source
# symptoms_pertaining_illness
# diagnosed_for
# diagnosis_source
# regular_treatment
# regular_treatment_source
# owner_status
# drinking_water_source
# water_filteration
# lighting_source
# cooking_fuel
# kitchen_availability
# is_television
# is_telephone
# is_washing_machine
# is_sewing_machine
# land_possessed
# residancial_status
# as_binned
# ----
# Old features :  ['age', 'alcohol_1.0', 'alcohol_2.0', 'alcohol_3.0', 'alcohol_4.0', 'as_binned_1.0', 'as_binned_2.0', 'as_binned_3.0', 'as_binned_4.0', 'as_binned_5.0', 'cart_1.0', 'cart_2.0', 'cart_3.0', 'cart_4.0', 'chew_1.0', 'chew_2.0', 'chew_3.0', 'chew_4.0', 'chew_5.0', 'chew_6.0', 'chew_7.0', 'cooking_fuel_0.0', 'cooking_fuel_1.0', 'cooking_fuel_2.0', 'cooking_fuel_3.0', 'cooking_fuel_4.0', 'cooking_fuel_5.0', 'cooking_fuel_6.0', 'cooking_fuel_7.0', 'cooking_fuel_8.0', 'cooking_fuel_9.0', 'currently_attending_school_1.0', 'currently_attending_school_2.0', 'currently_attending_school_3.0', 'diagnosis_source_0.0', 'diagnosis_source_1.0', 'diagnosis_source_10.0', 'diagnosis_source_11.0', 'diagnosis_source_13.0', 'diagnosis_source_2.0', 'diagnosis_source_3.0', 'diagnosis_source_4.0', 'diagnosis_source_5.0', 'diagnosis_source_6.0', 'diagnosis_source_7.0', 'diagnosis_source_8.0', 'diagnosis_source_9.0', 'diagnosis_source_99.0', 'disability_status_0.0', 'disability_status_1.0', 'disability_status_2.0', 'disability_status_3.0', 'disability_status_4.0', 'disability_status_5.0', 'disability_status_6.0', 'disability_status_7.0', 'district', 'drinking_water_source_1.0', 'drinking_water_source_2.0', 'drinking_water_source_3.0', 'drinking_water_source_4.0', 'drinking_water_source_5.0', 'drinking_water_source_6.0', 'drinking_water_source_7.0', 'drinking_water_source_8.0', 'drinking_water_source_9.0', 'healthscheme_1_1.0', 'healthscheme_1_2.0', 'healthscheme_1_3.0', 'healthscheme_1_4.0', 'healthscheme_1_5.0', 'healthscheme_1_6.0', 'healthscheme_1_7.0', 'healthscheme_2_1.0', 'healthscheme_2_2.0', 'healthscheme_2_3.0', 'healthscheme_2_4.0', 'healthscheme_2_5.0', 'healthscheme_2_6.0', 'healthscheme_2_7.0', 'highest_qualification_0.0', 'highest_qualification_1.0', 'highest_qualification_2.0', 'highest_qualification_3.0', 'highest_qualification_4.0', 'highest_qualification_5.0', 'highest_qualification_6.0', 'highest_qualification_7.0', 'highest_qualification_8.0', 'highest_qualification_9.0', 'house_status_1.0', 'house_status_2.0', 'house_status_3.0', 'house_status_4.0', 'house_structure_1.0', 'house_structure_2.0', 'house_structure_3.0', 'house_structure_4.0', 'household_have_electricity_1.0', 'household_have_electricity_2.0', 'householdstatus_1.0', 'householdstatus_2.0', 'householdstatus_3.0', 'householdstatus_4.0', 'householdstatus_5.0', 'householdstatus_6.0', 'housestatus_1.0', 'housestatus_3.0', 'illness_type_0.0', 'illness_type_1.0', 'illness_type_2.0', 'illness_type_3.0', 'illness_type_4.0', 'illness_type_5.0', 'illness_type_6.0', 'illness_type_7.0', 'illness_type_8.0', 'illness_type_9.0', 'injury_treatment_type_0.0', 'injury_treatment_type_1.0', 'injury_treatment_type_2.0', 'injury_treatment_type_3.0', 'injury_treatment_type_4.0', 'injury_treatment_type_5.0', 'injury_treatment_type_6.0', 'injury_treatment_type_7.0', 'is_bicycle_1.0', 'is_bicycle_2.0', 'is_car_1.0', 'is_car_2.0', 'is_computer_1.0', 'is_computer_2.0', 'is_computer_3.0', 'is_radio_1.0', 'is_radio_2.0', 'is_refrigerator_1.0', 'is_refrigerator_2.0', 'is_scooter_1.0', 'is_scooter_2.0', 'is_sewing_machine_1.0', 'is_sewing_machine_2.0', 'is_telephone_1.0', 'is_telephone_2.0', 'is_telephone_3.0', 'is_telephone_4.0', 'is_television_1.0', 'is_television_2.0', 'is_toilet_shared_1.0', 'is_toilet_shared_2.0', 'is_tractor_1.0', 'is_tractor_2.0', 'is_washing_machine_1.0', 'is_washing_machine_2.0', 'is_water_filter_1.0', 'is_water_filter_2.0', 'is_water_pump_1.0', 'is_water_pump_2.0', 'iscoveredbyhealthscheme_1.0', 'iscoveredbyhealthscheme_2.0', 'iscoveredbyhealthscheme_3.0', 'kitchen_availability_1.0', 'kitchen_availability_2.0', 'kitchen_availability_3.0', 'kitchen_availability_4.0', 'kitchen_availability_5.0', 'land_possessed_1.0', 'land_possessed_2.0', 'land_possessed_3.0', 'land_possessed_4.0', 'land_possessed_5.0', 'land_possessed_6.0', 'lighting_source_1.0', 'lighting_source_2.0', 'lighting_source_3.0', 'lighting_source_4.0', 'lighting_source_5.0', 'lighting_source_6.0', 'mar ...
# New features :  ['drinking_water_source_2.0', 'drinking_water_source_3.0', 'drinking_water_source_4.0', 'drinking_water_source_5.0', 'drinking_water_source_6.0', 'drinking_water_source_7.0', 'drinking_water_source_8.0', 'drinking_water_source_9.0', 'healthscheme_1_1.0', 'healthscheme_1_2.0', 'healthscheme_1_3.0', 'healthscheme_1_4.0', 'healthscheme_1_5.0', 'healthscheme_1_6.0', 'healthscheme_1_7.0', 'healthscheme_2_1.0', 'healthscheme_2_2.0', 'healthscheme_2_3.0', 'healthscheme_2_4.0', 'healthscheme_2_5.0', 'healthscheme_2_6.0', 'healthscheme_2_7.0', 'highest_qualification_0.0', 'highest_qualification_1.0', 'highest_qualification_2.0', 'highest_qualification_3.0', 'highest_qualification_4.0', 'highest_qualification_5.0', 'highest_qualification_6.0', 'highest_qualification_7.0', 'highest_qualification_8.0', 'highest_qualification_9.0', 'house_status_1.0', 'house_status_2.0', 'house_status_3.0', 'house_status_4.0', 'house_structure_1.0', 'house_structure_2.0', 'house_structure_3.0', 'house_structure_4.0', 'household_have_electricity_1.0', 'household_have_electricity_2.0', 'householdstatus_1.0', 'householdstatus_2.0', 'householdstatus_3.0', 'householdstatus_4.0', 'householdstatus_5.0', 'householdstatus_6.0', 'housestatus_1.0', 'housestatus_3.0', 'illness_type_0.0', 'illness_type_1.0', 'illness_type_2.0', 'illness_type_3.0', 'illness_type_4.0', 'illness_type_5.0', 'illness_type_6.0', 'illness_type_7.0', 'illness_type_8.0', 'illness_type_9.0', 'injury_treatment_type_0.0', 'injury_treatment_type_1.0', 'injury_treatment_type_2.0', 'injury_treatment_type_3.0', 'injury_treatment_type_4.0', 'injury_treatment_type_5.0', 'injury_treatment_type_6.0', 'injury_treatment_type_7.0', 'is_bicycle_1.0', 'is_bicycle_2.0', 'is_car_1.0', 'is_car_2.0', 'is_computer_1.0', 'is_computer_2.0', 'is_computer_3.0', 'is_radio_1.0', 'is_radio_2.0', 'is_refrigerator_1.0', 'is_refrigerator_2.0', 'is_scooter_1.0', 'is_scooter_2.0', 'is_sewing_machine_1.0', 'is_sewing_machine_2.0', 'is_telephone_1.0', 'is_telephone_2.0', 'is_telephone_3.0', 'is_telephone_4.0', 'is_television_1.0', 'is_television_2.0', 'is_toilet_shared_1.0', 'is_toilet_shared_2.0', 'is_tractor_1.0', 'is_tractor_2.0', 'is_washing_machine_1.0', 'is_washing_machine_2.0', 'is_water_filter_1.0', 'is_water_filter_2.0', 'is_water_pump_1.0', 'is_water_pump_2.0', 'iscoveredbyhealthscheme_1.0', 'iscoveredbyhealthscheme_2.0', 'iscoveredbyhealthscheme_3.0', 'kitchen_availability_1.0', 'kitchen_availability_2.0', 'kitchen_availability_3.0', 'kitchen_availability_4.0', 'kitchen_availability_5.0', 'land_possessed_1.0', 'land_possessed_2.0', 'land_possessed_3.0', 'land_possessed_4.0', 'land_possessed_5.0', 'land_possessed_6.0', 'lighting_source_1.0', 'lighting_source_2.0', 'lighting_source_3.0', 'lighting_source_4.0', 'lighting_source_5.0', 'lighting_source_6.0', 'marital_status_1.0', 'marital_status_2.0', 'marital_status_3.0', 'marital_status_4.0', 'marital_status_5.0', 'marital_status_6.0', 'marital_status_7.0', 'marital_status_8.0', 'occupation_status_1.0', 'occupation_status_10.0', 'occupation_status_11.0', 'occupation_status_13.0', 'occupation_status_14.0', 'occupation_status_15.0', 'occupation_status_16.0', 'occupation_status_2.0', 'occupation_status_3.0', 'occupation_status_4.0', 'occupation_status_5.0', 'occupation_status_6.0', 'occupation_status_7.0', 'occupation_status_8.0', 'occupation_status_9.0', 'owner_status_1.0', 'owner_status_2.0', 'owner_status_3.0', 'reason_for_not_attending_school_1.0', 'reason_for_not_attending_school_2.0', 'reason_for_not_attending_school_3.0', 'reason_for_not_attending_school_4.0', 'reason_for_not_attending_school_5.0', 'reason_for_not_attending_school_6.0', 'reason_for_not_attending_school_7.0', 'reason_for_not_attending_school_8.0', 'reason_for_not_attending_school_9.0', 'regular_treatment_1.0', 'regular_treatment_2.0', 'regular_treatment_3.0', 'regular_treatment_source_0.0', 'regular_treatment_source_1.0', 'regular_treatment_source_10.0', 'regular_treatment_source_11.0' ...
#
# Features Removed :  highest_qualification
# Train dataset :  (94821, 244) (94821, 7)
# Test dataset :  (39509, 244) (39509, 7)
# Validation Dataset :  (23706, 244) (23706, 7)
